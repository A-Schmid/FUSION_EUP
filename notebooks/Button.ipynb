# %%
import time
import sys
sys.path.append("..")
from FUSION import Button
from FUSION import email

# %%
# Initialisierung des BH1750-Lichtintensitätssensors
bh1750 = BH1750(node_name = "light_sensor", node_location="1104")

# Callbackfunktion, die bei jeder Messung aufgerufen werden soll
def on_light(data):
    # Ausgabe der gemessenen Lichtintensität
    print(data, "Einheiten Lichtintesität")

# Registrieren der oben definierten Callbackfunktion
bh1750.OnUpdate(on_light, "light_intensity")

time.sleep(60)
# Out:
# start
# disconnected buttonvariables set
#
# disconnected dht
# callback set
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# press
# The message could not be sent.
# release
# press
# disconnected dht
# disconnected button
# The message could not be sent.
# disconnected button
# release
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# press
# The message could not be sent.
# release
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dhtdisconnected button
#
# disconnected button
# disconnected buttondisconnected dht
#
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dhtdisconnected button
#
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected dhtdisconnected button
#
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button
# disconnected button
# disconnected dht
# disconnected button

# %%
import time
import sys
sys.path.append("..")
from FUSION import DHT11

# Initialisierung des DHT11 Feuchtigkeits- und Temperatursensors
dht = DHT11(node_name = "dht", node_location="1104")

# Callbackfunktion, die bei neu gemessenen Temperaturen aufgerufen wird
def on_temperature(data):
    print(data, "Grad")

# Callbackfunktion, die bei neu gemessenen Feuchtigkeitswerten aufgerufen wird
def on_humidity(data):
    print(data, "Prozent")

# Registrieren der oben definierten Callbackfunktionen
dht.OnUpdate(on_temperature, "temperature")
dht.OnUpdate(on_humidity, "humidity")

print("hallo");

time.sleep(60)
