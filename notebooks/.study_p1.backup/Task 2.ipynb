# %%
import time
import sys
sys.path.append("../..")
from FUSION import DHT11, Button, email

# %%
# your code goes here
mail_recipient = "vitus.maierhoefer@gmail.com"
mail_subject = "FUSION"
mail_message = ""

temperature = -1


dht = DHT11(node_name = "dht", node_location="1104")
btn = Button(node_name = "button", node_location="1104")

def on_temperature(data):
    temperature = "{} Grad".format(data)
    print(temperature)
    
def on_change(data):
    print('Test')
    if(data == True):
        print("press")
        mail_message = " The current temperature is " + str(temperature) + '°C.'
        email.send_email(recipient=mail_recipient, subject=mail_subject, message=mail_message)
    else:
        print("release")

dht.OnUpdate(on_temperature, "temperature")
btn.OnUpdate(on_change, "button_state")

time.sleep(60)
# Out:
# 25 Grad
# 25 Grad25 Grad
# 25 Grad25 Grad
#
#
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad25 Grad
#
# 25 Grad
# 25 Grad25 Grad
#
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad25 Grad
# 25 Grad
#
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad25 Grad
#
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad25 Grad
# 25 Grad
#
# 25 Grad25 Grad
#
# 25 Grad
# 25 Grad25 Grad
#
# 25 Grad25 Grad
#
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad25 Grad
#
# 25 Grad
# 25 Grad
# 25 Grad25 Grad25 Grad
# 25 Grad
# 25 Grad
#
# 25 Grad
#
# 25 Grad25 Grad
#
# 25 Grad
# 25 Grad
# 25 Grad
# 25 Grad
# press
# pressTest
# press
# presspress
# Test
# press
#
#
# release
# releaseTest
# Testrelease
#
# release
#
# release
# release
